# %% [markdown]
# # input function

# %%
x = "Manoj"
print(x)
# Out:
# Manoj

# %%
y = input()
print(y)
# Out:
# ITKannadigaru

# %%
y = input("Enter you name: ")
print(y)
# Out:
# Manoj

# %%
y = input("Enter you name: ")
print(f"Your name is {y}")
# Out:
# Your name is Manoj

# %%
name = input("Enter you name: ")
age = input("enter your age: ")
print(f"your name is {name}, and your age is {age}")
# Out:
# your name is Manoj, and your age is 48

# %%
name = input("Enter you name: ")
age = input("enter your age: ")
print(f"your name is {name}, and your age is {age+20}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 name = input("Enter you name: ")
#       2 age = input("enter your age: ")
# ----> 3 print(f"your name is {name}, and your age is {age+20}")
#
# TypeError: can only concatenate str (not "int") to str

# %%
name = input("Enter you name: ")
age = input("enter your age: ")
print(f"your name is {name}")
print( age+20)
# Out:
# your name is Manoj
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 age = input("enter your age: ")
#       3 print(f"your name is {name}")
# ----> 4 print( age+20)
#
# TypeError: can only concatenate str (not "int") to str

# %%
name = input("Enter you name: ")
age = input("enter your age: ")
print(f"your name is {name}")
type(name)
type(age)
# Out:
# your name is Manoj
# str

# %%
name = input("Enter you name: ")
age = input("enter your age: ")
print(f"your name is {name}")
temp = int(age)
type(name)
type(temp)
print(temp+10)
# Out:
# your name is Manoj
# 20

# %%
n = input()
print(n)
print(type(n))
# Out:
# 10
# <class 'str'>

# %%
n = int(input())
print(n)
print(type(n))
# Out:
# 10
# <class 'int'>

# %%
li = [1,2,3,4]
print(li)
# Out:
# [1, 2, 3, 4]

# %%
li = []
n = 3
for i in range(n):
    temp = input()
    li.append(temp)

print(li)
# Out:
# ['10', '20', '30']

# %%
li = []
n = 3
for i in range(n):
    temp = input()
    li.append(temp)

print(li)
type(temp)
# Out:
# ['', '10', '10']
# str

# %%
li = []
n = 3
for i in range(n):
    temp = int(input())
    li.append(temp)

print(li)
type(temp)
# Out:
# [10, 20, 30]
# int

# %%
s="1 4 5 6"
print(s)
# Out:
# 1 4 5 6

# %%
s=input()
print(s)
# Out:
#  1 4 5 6

# %%
s=input()
temp = s.split()
print(temp)
# Out:
# ['1', '4', '6', '4']

# %%
s="1 4 5 6"
temp = s.split()
print(temp)
# Out:
# ['1', '4', '5', '6']

# %%
s="1,4,5,6"
# default separator is space
temp = s.split()
print(temp)
# Out:
# ['1,4,5,6']

# %%
s="1,4,5,6"
temp = s.split(',')
print(temp)
# Out:
# ['1', '4', '5', '6']

# %%
li = []
s="1,4,5,6"
temp = s.split(',')
print(temp)
# Out:
# ['1', '4', '5', '6']

# %%
li = []
s="1,4,5,6"
temp = s.split(',')
for i in range(len(temp)):
    val = temp[i]
    li.append(int(val))
print(li)
# Out:
# [1, 4, 5, 6]

# %%
s="1,4,5,6"
li = list(map(int,s.split(',')))
print(li)
# Out:
# [1, 4, 5, 6]

# %%
s = '1 2 3 4'
temp = s.split()
print(temp)
# Out:
# ['1', '2', '3', '4']

# %%
temp = '1 2 3 4'.split()
print(temp)
# Out:
# ['1', '2', '3', '4']

# %%
li = map(int,'1 2 3 4'.split())
print(li)

# %%
li = list(map(int,'1 2 3 4'.split()))
print(li)
# Out:
# [1, 2, 3, 4]

# %%
li = list(map(int,input().split()))
print(li)
# Out:
# [10, 20, 30, 40]

# %%
li = list(map(int,input().split()))
print(li)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 li = list(map(int,input().split()))
#       2 print(li)
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
li = list(map(eval,input().split()))
print(li)
# Out:
# [10.5, 20.5, 40.6, 1, 3, 5]

# %%
li = list(map(eval,input().split()))
print(li)
# Out:
# ['test', 40, 50, 20.5]
