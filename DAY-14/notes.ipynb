# %% [markdown]
# https://leetcode.com/problems/best-time-to-buy-and-sell-stock/description/

# %%
r = 3 

for i in range(r):
    print(i)
    for j in range(r):
        print(i,j)
# Out:
# 0
# 0 0
# 0 1
# 0 2
# 1
# 1 0
# 1 1
# 1 2
# 2
# 2 0
# 2 1
# 2 2

# %%
r = 3 

for i in range(r):
    print(i)
    for j in range(r):
        print(j,end=' ')
    print()
# Out:
# 0
# 0 1 2
# 1
# 0 1 2
# 2
# 0 1 2

# %%
r = 3 

for i in range(r):
    print(i)
    for j in range(r-i):
        print(j,end=' ')
    print()
# Out:
# 0
# 0 1 2
# 1
# 0 1
# 2
# 0

# %%
r = 3 

for i in range(r):
    # print(i)
    for j in range(r-i):
        print('-',end=' ')
    print()
# Out:
# - - -
# - -
# -

# %%
r = 3 

for i in range(r):
    # print(i)
    for j in range(r-i):
        print('-',end=' ')
    print('Itkannadigaru')
    
    print()
# Out:
# - - - Itkannadigaru
#
# - - Itkannadigaru
#
# - Itkannadigaru

# %%
r = 3 

for i in range(r):
    # print(i)
    for j in range(r-i):
        print('-',end=' ')
    temp=i*2+i
    for i in range(temp):
        print('*',end=' ')
    print()
# Out:
# - - -
# - - * * *
# - * * * * * *

# %%
r = 10
n = r-1
for i in range(r):
    # print(i)
    for j in range(n-i):
        print('-',end=' ')
    temp=i*2+1
    for i in range(temp):
        print('*',end=' ')
    print()
# Out:
# - - - - - - - - - *
# - - - - - - - - * * *
# - - - - - - - * * * * *
# - - - - - - * * * * * * *
# - - - - - * * * * * * * * *
# - - - - * * * * * * * * * * *
# - - - * * * * * * * * * * * * *
# - - * * * * * * * * * * * * * * *
# - * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * *

# %%
r = 10
n = r-1
for i in range(r):
    # print(i)
    for j in range(n-i):
        print(' ',end=' ')
    temp=i*2+1
    for i in range(temp):
        print('*',end=' ')
    print()
# Out:
#                   *
#                 * * *
#               * * * * *
#             * * * * * * *
#           * * * * * * * * *
#         * * * * * * * * * * *
#       * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * *

# %%
r = 10
n = r-1
for i in range(r):
    # print(i)
    for j in range(i):
        print(' ',end=' ')
    temp=r*2-1-(2*i) # 3*2-1-(2*0))
    for i in range(temp):
        print('*',end=' ')
    print()
# Out:
# * * * * * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * *
#       * * * * * * * * * * * * *
#         * * * * * * * * * * *
#           * * * * * * * * *
#             * * * * * * *
#               * * * * *
#                 * * *
#                   *

# %%
r=4
temp=r*2-1-(2*i)
temp
# Out:
# 7

# %%
r = 10
n = r-1
for i in range(r):
    # print(i)
    for j in range(n-i):
        print(' ',end=' ')
    temp=i*2+1
    for i in range(temp):
        print('*',end=' ')
    print()
for i in range(1,r):
    # print(i)
    for j in range(i):
        print(' ',end=' ')
    temp=r*2-1-(2*i) # 3*2-1-(2*0))
    for i in range(temp):
        print('*',end=' ')
    print()
# Out:
#                   *
#                 * * *
#               * * * * *
#             * * * * * * *
#           * * * * * * * * *
#         * * * * * * * * * * *
#       * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * *
#       * * * * * * * * * * * * *
#         * * * * * * * * * * *
#           * * * * * * * * *
#             * * * * * * *
#               * * * * *
#                 * * *
#                   *

# %%
r=10
n=r-1
for i in range(r-1,-1,-1):
    # print(i)
    for j in range(n-i):
        print(' ',end=' ')
    for i in range(i*2+1):
        print('*',end=' ')
    print()
# Out:
# * * * * * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * *
#       * * * * * * * * * * * * *
#         * * * * * * * * * * *
#           * * * * * * * * *
#             * * * * * * *
#               * * * * *
#                 * * *
#                   *

# %%
* * * * * * * * * * * * * * * * * * * 
  * * * * * * * * * * * * * * * * * 
    * * * * * * * * * * * * * * * 
      * * * * * * * * * * * * * 
        * * * * * * * * * * * 
          * * * * * * * * * 
            * * * * * * * 
              * * * * * 
                * * * 
                  *   
                * * * 
              * * * * * 
            * * * * * * * 
          * * * * * * * * * 
        * * * * * * * * * * * 
      * * * * * * * * * * * * * 
    * * * * * * * * * * * * * * * 
  * * * * * * * * * * * * * * * * * 
* * * * * * * * * * * * * * * * * * *
# Out:
#   File <string>:2
#     * * *
#           ^
# IndentationError: unindent does not match any outer indentation level
