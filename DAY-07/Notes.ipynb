# %% [markdown]
# # We are solving leetcode
# https://leetcode.com/problems/score-of-a-string/description/
#
# ![image.png](attachment:image.png)

# %%
diff=10-5
print(diff)
# Out:
# 5

# %%
diff=10-20
print(diff)
# Out:
# -10

# %%
diff=10-20
if diff < 0:
    diff=diff*-1

print(diff)
# Out:
# 10

# %%
diff=10-20
# absoulte difference abs
print(abs(diff))
# Out:
# 10

# %%
itkannadigaru="a"
print(itkannadigaru)
# Out:
# a

# %%
itkannadigaru="a"
print(ord(itkannadigaru))
# Out:
# 97

# %%
s="abcd"
a=ord(s[0])
b=ord(s[1])
c=ord(s[2])
d=ord(s[3])

print(a)
print(b)
print(c)    
print(d)
# Out:
# 97
# 98
# 99
# 100

# %%
diff=a-b
diff2=b-c
diff3=c-d

sum=diff+diff2+diff3
print(abs(sum))
# Out:
# 3

# %%
s="abcd"
n=len(s)

for i in range(n):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
s="abcd"
n=len(s)

for i in range(n):
    print(i)
    print(s[i])
# Out:
# 0
# a
# 1
# b
# 2
# c
# 3
# d

# %%
s="abcd"
n=len(s)

for i in range(n):
    print(i,i+1)
    print(s[i],s[i+1])
# Out:
# 0 1
# a b
# 1 2
# b c
# 2 3
# c d
# 3 4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 6
#       4 for i in range(n):
#       5     print(i,i+1)
# ----> 6     print(s[i],s[i+1])
#
# IndexError: string index out of range

# %%
s="abcd"
n=len(s)-1

for i in range(n):
    print(i,i+1)
    print(s[i],s[i+1])
# Out:
# 0 1
# a b
# 1 2
# b c
# 2 3
# c d

# %%
s="abcd"
n=len(s)-1

for i in range(n):
    # print(i,i+1)
    # print(s[i],s[i+1])
    diff=ord(s[i])-ord(s[i+1])
    print(abs(diff))
# Out:
# 1
# 1
# 1

# %%
li = [1,4,5,6]
sum = 0
for i in range(li):
    sum = sum +i

print(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 li = [1,4,5,6]
#       2 sum = 0
# ----> 3 for i in range(li):
#       4     sum = sum +i
#       6 print(sum)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
li = [1,4,5,6]
sum = 0
for i in range(len(li)-1):
    sum = sum +i 

print(sum)
# Out:
# 3

# %%
li = [1,4,5,6]
sum = 0
for i in range(len(li)):
    sum = sum + li[i] 

print(sum)
# Out:
# 16

# %%
s="abcd"
n=len(s)-1
sum 
for i in range(n):
    # print(i,i+1)
    # print(s[i],s[i+1])
    diff=ord(s[i])-ord(s[i+1])
    # print(abs(diff))
    sum = sum + diff

print(sum)
# Out:
# 13

# %%
s="abcd"
n=len(s)-1
sum = 0
for i in range(n):
    # print(i,i+1)
    # print(s[i],s[i+1])
    a=ord(s[i])
    b=ord(s[i+1])
    # print(abs(diff))
    diff = abs(a-b)
    sum = sum + diff

print(sum)
# Out:
# 3

# %%
s="abcd"
n=len(s)-1
sum = 0
for i in range(n):
    # print(i,i+1)
    # print(s[i],s[i+1])
    diff=ord(s[i])-ord(s[i+1])
    # print(abs(diff))
    sum = sum + abs(diff)

print(sum)
# Out:
# 3

# %%
n=len(s)-1
sum = 0
for i in range(n):
    diff=ord(s[i])-ord(s[i+1])
    sum = sum + abs(diff)

print(sum)
